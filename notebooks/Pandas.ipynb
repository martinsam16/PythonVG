# %%
import pandas as pd

# %% [markdown]
# # Series

# %%
serie = pd.Series([1, 1, 1, 1, 10, 29, 20, 1, 1, 0])
print(serie)
print(type(serie))
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4    10
# 5    29
# 6    20
# 7     1
# 8     1
# 9     0
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# # Dataframes

# %%
datos = [
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"},
    {"nombre": "Pedro", "edad": 11, "sexo": "M"},
    {"nombre": "Luisa", "edad": 90, "sexo": "F"},
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"},
    {"nombre": "Pedro", "edad": 11, "sexo": "M"},
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"},
    {"nombre": "Pedro", "edad": 11, "sexo": "M"},
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"},
    {"nombre": "Pedro", "edad": 11, "sexo": "M"},
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"},
    {"nombre": "Pedro", "edad": 11, "sexo": "M"},
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"},
    {"nombre": "Pedro", "edad": 11, "sexo": "M"},
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"},
    {"nombre": "Jose", "edad": 11, "sexo": "M"},
    {"nombre": "Juan", "edad": 23, "sexo": None},
    {"nombre": "Ana", "edad": 23, "sexo": None},
    {"nombre": "Pedro", "edad": 11, "sexo": None},
    {"nombre": "Luisa", "edad": 90, "sexo": None},
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"},
    {"nombre": "Pedro", "edad": 11, "sexo": "M"},
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"},
    {"nombre": "Pedro", "edad": 11, "sexo": "M"},
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"},
    {"nombre": "Pedro", "edad": 11, "sexo": "M"},
    {"nombre": "Juan", "edad": 31, "sexo": "M"},
    {"nombre": "Ana", "edad": 32, "sexo": "F"},
    {"nombre": "Pedro", "edad": 33, "sexo": "M"},
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"},
    {"nombre": "Pedro", "edad": 11, "sexo": "M"},
    {"nombre": "Juan", "edad": 25, "sexo": "M"},
    {"nombre": "Ana", "edad": 23, "sexo": "F"}
]

df = pd.DataFrame(datos)
print(df)
# Out:
#    nombre  edad  sexo
# 0    Juan    25     M
# 1     Ana    23     F
# 2   Pedro    11     M
# 3   Luisa    90     F
# 4    Juan    25     M
# 5     Ana    23     F
# 6   Pedro    11     M
# 7    Juan    25     M
# 8     Ana    23     F
# 9   Pedro    11     M
# 10   Juan    25     M
# 11    Ana    23     F
# 12  Pedro    11     M
# 13   Juan    25     M
# 14    Ana    23     F
# 15  Pedro    11     M
# 16   Juan    25     M
# 17    Ana    23     F
# 18  Pedro    11     M
# 19   Juan    25     M
# 20    Ana    23     F
# 21   Jose    11     M
# 22   Juan    23  None
# 23    Ana    23  None
# 24  Pedro    11  None
# 25  Luisa    90  None
# 26   Juan    25     M
# 27    Ana    23     F
# 28  Pedro    11     M
# 29   Juan    25     M
# 30    Ana    23     F
# 31  Pedro    11     M
# 32   Juan    25     M
# 33    Ana    23     F
# 34  Pedro    11     M
# 35   Juan    31     M
# 36    Ana    32     F
# 37  Pedro    33     M
# 38   Juan    25     M
# 39    Ana    23     F
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   nombre  edad sexo
# 0   Juan    25    M
# 1    Ana    23    F
# 2  Pedro    11    M
# 3  Luisa    90    F
# 4   Juan    25    M

# %%
nombres = df["nombre"]
nombres
# Out:
# 0      Juan
# 1       Ana
# 2     Pedro
# 3     Luisa
# 4      Juan
# 5       Ana
# 6     Pedro
# 7      Juan
# 8       Ana
# 9     Pedro
# 10     Juan
# 11      Ana
# 12    Pedro
# 13     Juan
# 14      Ana
# 15    Pedro
# 16     Juan
# 17      Ana
# 18    Pedro
# 19     Juan
# 20      Ana
# 21    Pedro
# 22     Juan
# 23      Ana
# 24    Pedro
# 25    Luisa
# 26     Juan
# 27      Ana
# 28    Pedro
# 29     Juan
# 30      Ana
# 31    Pedro
# 32     Juan
# 33      Ana
# 34    Pedro
# 35     Juan
# 36      Ana
# 37    Pedro
# 38     Juan
# 39      Ana
# 40    Pedro
# 41     Juan
# 42      Ana
# Name: nombre, dtype: object

# %%
fila_3 = df.loc[3]
fila_3
# Out:
# nombre    Luisa
# edad         90
# sexo          F
# Name: 3, dtype: object

# %%
mayores_de_treinta_anios = df.loc[df["edad"] > 30]
mayores_de_treinta_anios
# Out:
#    nombre  edad sexo
# 3   Luisa    90    F
# 25  Luisa    90    F
# 35   Juan    31    M
# 36    Ana    32    F
# 37  Pedro    33    M

# %%
loc_df = df.loc[2:4, "nombre":"edad"]
loc_df
# Out:
#   nombre  edad
# 2  Pedro    11
# 3  Luisa    90
# 4   Juan    25

# %%
iloc_df = df.iloc[:, 0:-1]
iloc_df
# Out:
#    nombre  edad
# 0    Juan    25
# 1     Ana    23
# 2   Pedro    11
# 3   Luisa    90
# 4    Juan    25
# 5     Ana    23
# 6   Pedro    11
# 7    Juan    25
# 8     Ana    23
# 9   Pedro    11
# 10   Juan    25
# 11    Ana    23
# 12  Pedro    11
# 13   Juan    25
# 14    Ana    23
# 15  Pedro    11
# 16   Juan    25
# 17    Ana    23
# 18  Pedro    11
# 19   Juan    25
# 20    Ana    23
# 21  Pedro    11
# 22   Juan    25
# 23    Ana    23
# 24  Pedro    11
# 25  Luisa    90
# 26   Juan    25
# 27    Ana    23
# 28  Pedro    11
# 29   Juan    25
# 30    Ana    23
# 31  Pedro    11
# 32   Juan    25
# 33    Ana    23
# 34  Pedro    11
# 35   Juan    31
# 36    Ana    32
# 37  Pedro    33
# 38   Juan    25
# 39    Ana    23
# 40  Pedro    11
# 41   Juan    25
# 42    Ana    23

# %%
query = df.query("nombre == 'Pedro'")
query
# Out:
#    nombre  edad sexo
# 2   Pedro    11    M
# 6   Pedro    11    M
# 9   Pedro    11    M
# 12  Pedro    11    M
# 15  Pedro    11    M
# 18  Pedro    11    M
# 21  Pedro    11    M
# 24  Pedro    11    M
# 28  Pedro    11    M
# 31  Pedro    11    M
# 34  Pedro    11    M
# 37  Pedro    33    M
# 40  Pedro    11    M

# %% [markdown]
# ## Funciones de filtrado en DataFrame
# * df.loc: etiquetas
# * df.iloc: indices numéricos
# * df.query: expresiones condicionales
# * df.isin: lista de valores
# * df.groupby: nos permite agrupar y aplicar una función de agregación

# %%
df.isna()
# Out:
#     nombre   edad   sexo
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 4    False  False  False
# 5    False  False  False
# 6    False  False  False
# 7    False  False  False
# 8    False  False  False
# 9    False  False  False
# 10   False  False  False
# 11   False  False  False
# 12   False  False  False
# 13   False  False  False
# 14   False  False  False
# 15   False  False  False
# 16   False  False  False
# 17   False  False  False
# 18   False  False  False
# 19   False  False  False
# 20   False  False  False
# 21   False  False  False
# 22   False  False   True
# 23   False  False   True
# 24   False  False   True
# 25   False  False   True
# 26   False  False  False
# 27   False  False  False
# 28   False  False  False
# 29   False  False  False
# 30   False  False  False
# 31   False  False  False
# 32   False  False  False
# 33   False  False  False
# 34   False  False  False
# 35   False  False  False
# ...

# %%
df.fillna("M")
# Out:
#    nombre  edad sexo
# 0    Juan    25    M
# 1     Ana    23    F
# 2   Pedro    11    M
# 3   Luisa    90    F
# 4    Juan    25    M
# 5     Ana    23    F
# 6   Pedro    11    M
# 7    Juan    25    M
# 8     Ana    23    F
# 9   Pedro    11    M
# 10   Juan    25    M
# 11    Ana    23    F
# 12  Pedro    11    M
# 13   Juan    25    M
# 14    Ana    23    F
# 15  Pedro    11    M
# 16   Juan    25    M
# 17    Ana    23    F
# 18  Pedro    11    M
# 19   Juan    25    M
# 20    Ana    23    F
# 21   Jose    11    M
# 22   Juan    23    M
# 23    Ana    23    M
# 24  Pedro    11    M
# 25  Luisa    90    M
# 26   Juan    25    M
# 27    Ana    23    F
# 28  Pedro    11    M
# 29   Juan    25    M
# 30    Ana    23    F
# 31  Pedro    11    M
# 32   Juan    25    M
# 33    Ana    23    F
# 34  Pedro    11    M
# 35   Juan    31    M
# 36    Ana    32    F
# 37  Pedro    33    M
# 38   Juan    25    M
# 39    Ana    23    F
# 40  Pedro    11    M
# 41   Juan    25    M
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#    nombre  edad sexo
# 0    Juan    25    M
# 1     Ana    23    F
# 2   Pedro    11    M
# 3   Luisa    90    F
# 4    Juan    25    M
# 5     Ana    23    F
# 6   Pedro    11    M
# 7    Juan    25    M
# 8     Ana    23    F
# 9   Pedro    11    M
# 10   Juan    25    M
# 11    Ana    23    F
# 12  Pedro    11    M
# 13   Juan    25    M
# 14    Ana    23    F
# 15  Pedro    11    M
# 16   Juan    25    M
# 17    Ana    23    F
# 18  Pedro    11    M
# 19   Juan    25    M
# 20    Ana    23    F
# 21   Jose    11    M
# 26   Juan    25    M
# 27    Ana    23    F
# 28  Pedro    11    M
# 29   Juan    25    M
# 30    Ana    23    F
# 31  Pedro    11    M
# 32   Juan    25    M
# 33    Ana    23    F
# 34  Pedro    11    M
# 35   Juan    31    M
# 36    Ana    32    F
# 37  Pedro    33    M
# 38   Juan    25    M
# 39    Ana    23    F
# 40  Pedro    11    M
# 41   Juan    25    M
# 42    Ana    23    F

# %% [markdown]
# # Proceso de ETL para obener el dataset final

# %%
import pandas as pd

ruta_csv = '/content/sample_data/california_housing_test.csv'

california_housing_test = pd.read_csv(ruta_csv)

# %%
california_housing_test.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
california_housing_test.shape
# Out:
# (3000, 9)

# %%
california_housing_test_transformation = california_housing_test.dropna()

# %%
california_housing_test_transformation.shape
# Out:
# (3000, 9)

# %%
path_save_xlsx = '/content/sample_data/california_housing_test.xlsx'
california_housing_test_transformation.to_excel(path_save_xlsx)
